# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# GPU Settings
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Mon Apr 12 01:32:33 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     6W /  75W |      0MiB /  7611MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install pytorch-transformers
# !sudo apt-get install libxml-parser-perl
# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 184kB 6.6MB/s
# ...
#      |████████████████████████████████| 870kB 19.4MB/s
# ...
#      |████████████████████████████████| 1.2MB 26.5MB/s
# ...
#      |████████████████████████████████| 133kB 35.8MB/s
# ...
#      |████████████████████████████████| 81kB 8.7MB/s
# ...
#      |████████████████████████████████| 7.4MB 28.3MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.44-cp37-none-any.whl size=886084 sha256=1318bb2cccc96e0350b1e4a4192f1a4601348a9deba017525302ad91f86dfbc3
#   Stored in directory: /root/.cache/pip/wheels/3e/fb/c0/13ab4d63d537658f448366744654323077c4d90069b6512f3c
# Successfully built sacremoses
# ERROR: botocore 1.20.49 has requirement urllib3<1.27,>=1.25.4, but you'll have urllib3 1.24.3 which is incompatible.
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libauthen-sasl-perl libdata-dump-perl libencode-locale-perl
# ...

# %%
cd /content/drive/MyDrive/PhD-CD/spring2021/nn4nlp/nn4nlp_project
# Out:
# /content/drive/MyDrive/PhD-CD/spring2021/nn4nlp/nn4nlp_project

# %%
ls
# Out:
# data/  files/  logs/  models/  pyrouge/  refs/  temp/

# %%
cd files
# Out:
# /content/drive/MyDrive/PhD-CD/spring2021/nn4nlp/nn4nlp_project/files

# %%
ls
# Out:
#  base.py                             preprocess.py
#  bert_data/                          presumm_evaluation.ipynb
#  bert_data_cnndm_final.zip           __pycache__/
#  bertext_cnndm_transformer.zip       pyrouge/
#  cal_rouge.py                        script_PreSumm.ipynb
# 'Copy of presumm_evaluation.ipynb'   train_abstractive.py
#  distributed.py                      train_extractive.py
#  models/                             train.py
#  others/                             train_xsum.ipynb
#  post_stats.py                       translate/
#  prepro/

# %%
# !pip install https://github.com/bheinzerling/pyrouge/archive/master.zip
# !pip install pyrouge
# !pip show pyrouge
# !git clone https://github.com/andersjo/pyrouge.git
from pyrouge import Rouge155
# !pyrouge_set_rouge_path 'pyrouge/tools/ROUGE-1.5.5'
# !chmod 777 'pyrouge/tools/ROUGE-1.5.5'
# !chmod 777 'pyrouge/tools/ROUGE-1.5.5/ROUGE-1.5.5.pl'
# Out:
# ...
#   Using cached https://github.com/bheinzerling/pyrouge/archive/master.zip
# ...
# ERROR: Operation cancelled by user
# ...
# Name: pyrouge
# Version: 0.1.3
# Summary: A Python wrapper for the ROUGE summarization evaluation package.
# Home-page: https://github.com/noutenki/pyrouge
# Author: Benjamin Heinzerling, Anders Johannsen
# Author-email: benjamin.heinzerling@h-its.org
# License: LICENSE.txt
# Location: /usr/local/lib/python3.7/dist-packages
# Requires:
# Required-by:
# fatal: destination path 'pyrouge' already exists and is not an empty directory.
# 2021-04-12 01:20:45,460 [MainThread  ] [INFO ]  Set ROUGE home directory to pyrouge/tools/ROUGE-1.5.5.

# %%
pwd
# Out:
# '/content/drive/My Drive/PhD-CD/spring2021/nn4nlp/nn4nlp_project/files'

# %%
# !pyrouge_set_rouge_path '/content/drive/MyDrive/PhD-CD/spring2021/nn4nlp/nn4nlp_project/files/pyrouge/tools/ROUGE-1.5.5'
# !chmod 777 '/content/drive/MyDrive/PhD-CD/spring2021/nn4nlp/nn4nlp_project/files/pyrouge/tools/ROUGE-1.5.5'
# Out:
# 2021-04-12 01:19:19,780 [MainThread  ] [INFO ]  Set ROUGE home directory to /content/drive/MyDrive/PhD-CD/spring2021/nn4nlp/nn4nlp_project/files/pyrouge/tools/ROUGE-1.5.5.

# %%
cd pyrouge
# Out:
# /content/drive/MyDrive/PhD-CD/spring2021/nn4nlp/nn4nlp_project/files/pyrouge

# %%
# !sudo python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing pyrouge.egg-info/PKG-INFO
# writing dependency_links to pyrouge.egg-info/dependency_links.txt
# writing requirements to pyrouge.egg-info/requires.txt
# writing top-level names to pyrouge.egg-info/top_level.txt
# writing manifest file 'pyrouge.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/pyrouge
# copying build/lib/pyrouge/__init__.py -> build/bdist.linux-x86_64/egg/pyrouge
# copying build/lib/pyrouge/base.py -> build/bdist.linux-x86_64/egg/pyrouge
# copying build/lib/pyrouge/rouge.py -> build/bdist.linux-x86_64/egg/pyrouge
# byte-compiling build/bdist.linux-x86_64/egg/pyrouge/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrouge/base.py to base.cpython-37.pyc
# ...

# %%
ls
# Out:
# build/  dist/    pyrouge/           README.md  tools/
# data/   LICENSE  pyrouge.egg-info/  setup.py

# %%
cd tools
# Out:
# /content/drive/My Drive/PhD-CD/spring2021/nn4nlp/nn4nlp_project/files/pyrouge/tools

# %%
ls
# Out:
# ROUGE-1.5.5/

# %%
cd ROUGE-1.5.5/
# Out:
# /content/drive/My Drive/PhD-CD/spring2021/nn4nlp/nn4nlp_project/files/pyrouge/tools/ROUGE-1.5.5

# %%
ls
# Out:
# data/  README.txt  RELEASE-NOTE.txt  ROUGE-1.5.5.pl*  runROUGE-test.pl  XML/

# %%
cd data
# Out:
# /content/drive/My Drive/PhD-CD/spring2021/nn4nlp/nn4nlp_project/files/pyrouge/tools/ROUGE-1.5.5/data

# %%
ls
# Out:
# smart_common_words.txt   WordNet-2.0.exc.db
# WordNet-1.6-Exceptions/  WordNet-2.0-Exceptions/

# %%
# !ln -sf WordNet-2.0-Exceptions/WordNet-2.0.exc.db WordNet-2.0.exc.db

# %%
ls
# Out:
# smart_common_words.txt   WordNet-2.0.exc.db@
# WordNet-1.6-Exceptions/  WordNet-2.0-Exceptions/

# %%
# !rm WordNet-2.0.exc.db

# %%
# !perl ./WordNet-2.0-Exceptions/buildExeptionDB.pl ./WordNet-2.0-Exceptions ./smart_common_words.txt ./WordNet-2.0.exc.db

# %%
ls
# Out:
# smart_common_words.txt   WordNet-2.0.exc.db
# WordNet-1.6-Exceptions/  WordNet-2.0-Exceptions/

# %%
# !python train.py -mode train -task ext -encoder bert -bert_data_path ../data/preprocessed_data/bert_data_xsum_final/bert_data_xsum_new/xsum -model_path ..data/trained_models/manuel/ -lr 2e-3 -visible_gpus 1 -report_every 50 -save_checkpoint_steps 1000 -batch_size 3000 -train_steps 50000 -accum_count 2 -log_file ../logs/bert_classifier -use_interval true -warmup_steps 10000
# Out:
# Device:  0
# ----TRAIN EXTRACTIVE----
# [2021-04-10 19:54:43,257 INFO] Device ID 0
# [2021-04-10 19:54:43,257 INFO] Device cuda
# [2021-04-10 19:54:43,301 INFO] loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at ../temp/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# [2021-04-10 19:54:43,553 INFO] Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
# ...

# %%
# !python train.py -mode train -task ext -encoder bert -bert_data_path ../data/preprocessed_data/bert_data_xsum_final/bert_data_xsum_new/xsum -model_path ..data/trained_models/ -train_from ..data/trained_models/model_step_10000.pt -lr 2e-3 -visible_gpus 1 -report_every 50 -save_checkpoint_steps 1000 -batch_size 3000 -train_steps 50000 -accum_count 2 -log_file ../logs/bert_classifier -use_interval true -warmup_steps 10000
# Out:
# Device:  0
# ----TRAIN EXTRACTIVE----
# [2021-04-11 00:09:18,732 INFO] Device ID 0
# [2021-04-11 00:09:19,048 INFO] Device cuda
# [2021-04-11 00:09:19,048 INFO] Loading checkpoint from ..data/trained_models/model_step_10000.pt
# ---TRAINING FROM:  ..data/trained_models/model_step_10000.pt
# [2021-04-11 00:09:41,868 INFO] loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at ../temp/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# [2021-04-11 00:09:42,369 INFO] Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
# ...

# %%
# !python train.py -mode train -task ext -encoder bert -bert_data_path ../data/preprocessed_data/bert_data_xsum_final/bert_data_xsum_new/xsum -model_path ..data/trained_models/ -train_from ..data/trained_models/model_step_19000.pt -lr 2e-3 -visible_gpus 1 -report_every 50 -save_checkpoint_steps 1000 -batch_size 3000 -train_steps 50000 -accum_count 2 -log_file ../logs/bert_classifier -use_interval true -warmup_steps 10000
# Out:
# Device:  0
# ----TRAIN EXTRACTIVE----
# [2021-04-11 12:25:30,603 INFO] Device ID 0
# [2021-04-11 12:25:31,245 INFO] Device cuda
# [2021-04-11 12:25:31,246 INFO] Loading checkpoint from ..data/trained_models/model_step_19000.pt
# ---TRAINING FROM:  ..data/trained_models/model_step_19000.pt
# [2021-04-11 12:26:05,514 INFO] loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at ../temp/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# [2021-04-11 12:26:06,276 INFO] Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
# ...

# %%
# !python train.py -mode train -task ext -encoder bert -bert_data_path ../data/preprocessed_data/bert_data_xsum_final/bert_data_xsum_new/xsum -model_path ..data/trained_models/ -train_from ..data/trained_models/model_step_24000.pt -lr 2e-3 -visible_gpus 1 -report_every 50 -save_checkpoint_steps 1000 -batch_size 3000 -train_steps 50000 -accum_count 2 -log_file ../logs/bert_classifier -use_interval true -warmup_steps 10000
# Out:
# Device:  0
# ----TRAIN EXTRACTIVE----
# [2021-04-12 01:32:50,059 INFO] Device ID 0
# [2021-04-12 01:32:50,060 INFO] Device cuda
# [2021-04-12 01:32:50,060 INFO] Loading checkpoint from ..data/trained_models/model_step_24000.pt
# ---TRAINING FROM:  ..data/trained_models/model_step_24000.pt
# [2021-04-12 01:33:11,382 INFO] loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at ../temp/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# [2021-04-12 01:33:11,383 INFO] Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
# ...
